# %% [markdown]
# ## 1. Load data

# %%
from process import *

data = load_data(DatasetDirectory.BANK)

# %% [markdown]
# ## 2. Prepare datasets

# %% [markdown]
# ### 2.1. shuffle and split dataset

# %%
data_preprocessing(data=data, dataset_directory=DatasetDirectory.BANK)
ratios = ["40_60", "60_40", "80_20", "90_10"]

datasets = {
    "40_60": (prepare_dataset_v2(data, train_ratio=0.4, test_ratio=0.6,
                dataset_directory=DatasetDirectory.BANK)),
    "60_40": (prepare_dataset_v2(data, train_ratio=0.6, test_ratio=0.4,
                dataset_directory=DatasetDirectory.BANK)),
    "80_20": (prepare_dataset_v2(data, train_ratio=0.8, test_ratio=0.2,
                dataset_directory=DatasetDirectory.BANK)),
    "90_10": (prepare_dataset_v2(data, train_ratio=0.9, test_ratio=0.1,
                dataset_directory=DatasetDirectory.BANK)),
    }

# %% [markdown]
# ### 2.2. Visualize the class distributions

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(12, 18))
sns.set(style="darkgrid")

plt.subplot(5, 2, 1)
ax = sns.countplot(x=data['y'])
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width()/2., p.get_height()))
plt.title('Original Dataset')
plt.ylabel('Count')
plt.xlabel('Value')
plt.subplot(5, 2, 2)
plt.axis('off')

for i, ratio in enumerate(ratios): 
    label_train = datasets[ratio][1]
    label_test = datasets[ratio][3]
    
    # Train
    plt.subplot(5, 2, 2*(i+1) + 1)
    ax1 = sns.countplot(x=label_train)
    for p in ax1.patches:
        ax1.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width()/2., p.get_height()),
                     ha='center', va='bottom', fontsize=10, color='black')
    plt.title(f'Train ({ratio})')
    plt.ylabel('Count')
    plt.xlabel('Class')

    # Test
    plt.subplot(5, 2, 2*(i+1) + 2)
    ax2 = sns.countplot(x=label_test)
    for p in ax2.patches:
        ax2.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width()/2., p.get_height()),
                     ha='center', va='bottom', fontsize=10, color='black')
    plt.title(f'Test ({ratio})')
    plt.ylabel('Count')
    plt.xlabel('Class')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Build the decision tree classifier

# %% [markdown]
# ### 3.1 Build model

# %%
from sklearn.tree import DecisionTreeClassifier

clfs = {}
label_preds = {}
for ratio in ratios:
    feature_train, label_train, feature_test, label_test = datasets[ratio]
    clf = DecisionTreeClassifier(criterion="entropy", random_state=42, max_depth=None)
    clf.fit(feature_train, label_train)
    clfs[ratio] = clf
    label_preds[ratio] = clf.predict(feature_test)

# %% [markdown]
# ### 3.2 Visualize the decision tree

# %%
import graphviz
from sklearn import tree
import os
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

outputRatio_dir = os.path.join(os.getcwd(), "png", "bank", "ratio")
os.makedirs(outputRatio_dir, exist_ok=True)

plt.figure(figsize=(28,20))
for i, ratio in enumerate(clfs.keys()):
    plt.subplot(2, 2, i+1)
    clf = clfs[ratio]
    plot_tree(clf, 
            feature_names=[col for col in data.columns if col != "y"],
            class_names=[str(i) for i in sorted(set(datasets[ratio][1]))],
            filled=True, rounded=True)
    plt.title(f"Decision Tree ({ratio})")
    
    dot_data = tree.export_graphviz(clf, out_file=None,
            feature_names=[col for col in data.columns if col != "y"],
            class_names=[str(i) for i in sorted(set(datasets[ratio][1]))],
            filled=True, rounded=True,
            special_characters=True)

    graph = graphviz.Source(dot_data)
    name_ratio = f'bank_tree_{ratio}'
    graph.render(filename=os.path.join(outputRatio_dir, name_ratio), format='png', cleanup=True)
    print(f"Decision tree visualization for ratio = {ratio} was saved")
    print(f"{outputRatio_dir}/{name_ratio}.png")

plt.tight_layout()
plt.show()
# Out:
# (process:24880): Pango-CRITICAL **: 18:45:25.136: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:24880): Pango-CRITICAL **: 18:45:25.136: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:24880): Pango-CRITICAL **: 18:45:25.136: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:24880): Pango-CRITICAL **: 18:45:25.136: pango_font_description_get_family: assertion 'desc != NULL' failed
# Decision tree visualization for ratio = 40_60 was saved
# d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\ratio/bank_tree_40_60.png
# (process:7432): Pango-CRITICAL **: 18:45:26.976: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:7432): Pango-CRITICAL **: 18:45:26.976: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:7432): Pango-CRITICAL **: 18:45:26.976: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:7432): Pango-CRITICAL **: 18:45:26.976: pango_font_description_get_family: assertion 'desc != NULL' failed
# Decision tree visualization for ratio = 60_40 was saved
# d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\ratio/bank_tree_60_40.png
# (process:21240): Pango-CRITICAL **: 18:45:29.334: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:21240): Pango-CRITICAL **: 18:45:29.334: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:21240): Pango-CRITICAL **: 18:45:29.334: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:21240): Pango-CRITICAL **: 18:45:29.334: pango_font_description_get_family: assertion 'desc != NULL' failed
# Decision tree visualization for ratio = 80_20 was saved
# d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\ratio/bank_tree_80_20.png
# (process:23148): Pango-CRITICAL **: 18:45:32.351: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:23148): Pango-CRITICAL **: 18:45:32.351: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:23148): Pango-CRITICAL **: 18:45:32.351: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:23148): Pango-CRITICAL **: 18:45:32.351: pango_font_description_get_family: assertion 'desc != NULL' failed
# Decision tree visualization for ratio = 90_10 was saved
# d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\ratio/bank_tree_90_10.png

# %% [markdown]
# ## 4. Evaluating the decision tree classifiers

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

accuracies = {}

for ratio in ratios:
    print(f'---------------- {ratio} --------------------')
    feature_train, label_train, feature_test, label_test = datasets[ratio]
    accuracy = accuracy_score(label_test, label_preds[ratio])
    accuracies[ratio] = accuracy
    print(f"Accuracy: {accuracy:.2f}")

    print("Classification Report:")
    print(classification_report(label_test, label_preds[ratio]))

    print("Confusion Matrix:")
    print(confusion_matrix(label_test, label_preds[ratio]))
    

accuracy_values = [accuracies[ratio] for ratio in ratios]

plt.figure(figsize=(10, 5))
plt.plot(ratios, accuracy_values, marker='o', linestyle='-', color='blue')
plt.title('Độ chính xác theo từng tỉ lệ train/test')
plt.xlabel('Tỉ lệ train/test')
plt.ylabel('Độ chính xác')
plt.ylim(0, 1)
for i, acc in enumerate(accuracy_values):
    plt.text(ratios[i], acc + 0.01, f"{acc:.2f}", ha='center', fontsize=10)
plt.grid(True)
plt.show()
# Out:
# ---------------- 40_60 --------------------
# Accuracy: 0.87
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      2408
#            1       0.42      0.40      0.41       305
#
#     accuracy                           0.87      2713
#    macro avg       0.67      0.67      0.67      2713
# weighted avg       0.87      0.87      0.87      2713
#
# Confusion Matrix:
# [[2242  166]
#  [ 183  122]]
# ---------------- 60_40 --------------------
# Accuracy: 0.87
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93      1620
#            1       0.39      0.44      0.41       189
#
#     accuracy                           0.87      1809
#    macro avg       0.66      0.68      0.67      1809
# weighted avg       0.88      0.87      0.87      1809
#
# Confusion Matrix:
# [[1488  132]
#  [ 106   83]]
# ---------------- 80_20 --------------------
# Accuracy: 0.89
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94       807
#            1       0.47      0.44      0.46        98
#
#     accuracy                           0.89       905
#    macro avg       0.70      0.69      0.70       905
# weighted avg       0.88      0.89      0.88       905
#
# Confusion Matrix:
# [[759  48]
#  [ 55  43]]
# ---------------- 90_10 --------------------
# Accuracy: 0.87
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       406
#            1       0.37      0.43      0.40        47
#
#     accuracy                           0.87       453
#    macro avg       0.65      0.67      0.66       453
# weighted avg       0.87      0.87      0.87       453
#
# Confusion Matrix:
# [[372  34]
#  [ 27  20]]

# %% [markdown]
# ## 5. The depth and accuracy of a decision tree

# %%
import graphviz
from sklearn import tree
import os

feature_train, label_train, feature_test, label_test = datasets["80_20"]
depth = [None, 2, 3, 4, 5, 6, 7]
depth_labels = ['None' if d is None else str(d) for d in depth]
accuracy_by_depth = []
output_dir = os.path.join(os.getcwd(), "png", "bank", "depth")
os.makedirs(output_dir, exist_ok=True)

for dep in depth:
    clf = DecisionTreeClassifier(criterion="entropy", random_state=42, max_depth=dep)
    clf.fit(feature_train, label_train)
    label_preds = clf.predict(feature_test)
    accuracy = accuracy_score(label_test, label_preds)
    accuracy_by_depth.append(accuracy)
    dot_data = tree.export_graphviz(clf, out_file=None,
            feature_names=[col for col in data.columns if col != "y"],
            class_names=[str(i) for i in np.unique(label_train)],
            filled=True, rounded=True,
            special_characters=True)
    graph = graphviz.Source(dot_data)
    name = f'bank_tree_{dep}'
    graph.render(filename=os.path.join(output_dir, name), format='png', cleanup=True)
    print(f"Depth: {dep}")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Saved to {output_dir}/{name}.png")
    
plt.figure(figsize=(8, 5))
plt.plot(depth_labels, accuracy_by_depth, marker='o', linestyle='-', color='green')
plt.title('Độ chính xác của mô hình theo từng độ sâu với tỉ lệ 80/20')
plt.xlabel('Độ sâu của cây')
plt.ylabel('Độ chính xác')
plt.ylim(0, 1)
for i, acc in enumerate(accuracy_by_depth):
    plt.text(depth_labels[i], acc + 0.01, f"{acc:.2f}", ha='center', fontsize=10)
plt.grid(True)
plt.show()
# Out:
# (process:26412): Pango-CRITICAL **: 18:47:03.497: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:26412): Pango-CRITICAL **: 18:47:03.497: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:26412): Pango-CRITICAL **: 18:47:03.497: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:26412): Pango-CRITICAL **: 18:47:03.497: pango_font_description_get_family: assertion 'desc != NULL' failed
# Depth: None
# Accuracy: 0.89
# Saved to d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\depth/bank_tree_None.png
# (process:27592): Pango-CRITICAL **: 18:47:05.786: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:27592): Pango-CRITICAL **: 18:47:05.786: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:27592): Pango-CRITICAL **: 18:47:05.786: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:27592): Pango-CRITICAL **: 18:47:05.786: pango_font_description_get_family: assertion 'desc != NULL' failed
# Depth: 2
# Accuracy: 0.89
# Saved to d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\depth/bank_tree_2.png
# (process:9116): Pango-CRITICAL **: 18:47:06.209: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:9116): Pango-CRITICAL **: 18:47:06.209: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:9116): Pango-CRITICAL **: 18:47:06.209: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:9116): Pango-CRITICAL **: 18:47:06.209: pango_font_description_get_family: assertion 'desc != NULL' failed
# Depth: 3
# Accuracy: 0.90
# Saved to d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\depth/bank_tree_3.png
# (process:23400): Pango-CRITICAL **: 18:47:06.637: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:23400): Pango-CRITICAL **: 18:47:06.637: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:23400): Pango-CRITICAL **: 18:47:06.637: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:23400): Pango-CRITICAL **: 18:47:06.637: pango_font_description_get_family: assertion 'desc != NULL' failed
# Depth: 4
# Accuracy: 0.90
# Saved to d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\depth/bank_tree_4.png
# (process:21968): Pango-CRITICAL **: 18:47:07.119: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:21968): Pango-CRITICAL **: 18:47:07.119: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:21968): Pango-CRITICAL **: 18:47:07.119: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:21968): Pango-CRITICAL **: 18:47:07.119: pango_font_description_get_family: assertion 'desc != NULL' failed
# Depth: 5
# Accuracy: 0.90
# Saved to d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\depth/bank_tree_5.png
# (process:13388): Pango-CRITICAL **: 18:47:07.717: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:13388): Pango-CRITICAL **: 18:47:07.717: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:13388): Pango-CRITICAL **: 18:47:07.717: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:13388): Pango-CRITICAL **: 18:47:07.717: pango_font_description_get_family: assertion 'desc != NULL' failed
# Depth: 6
# Accuracy: 0.90
# Saved to d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\depth/bank_tree_6.png
# (process:22824): Pango-CRITICAL **: 18:47:08.337: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:22824): Pango-CRITICAL **: 18:47:08.337: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:22824): Pango-CRITICAL **: 18:47:08.337: pango_font_description_get_family: assertion 'desc != NULL' failed
#
# (process:22824): Pango-CRITICAL **: 18:47:08.337: pango_font_description_get_family: assertion 'desc != NULL' failed
# Depth: 7
# Accuracy: 0.91
# Saved to d:\NAM3_HK2\CSTNTT\DT\DecisionTree\png\bank\depth/bank_tree_7.png
